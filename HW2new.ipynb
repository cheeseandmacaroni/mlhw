# %% [markdown]
# **Датасет:**https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata
#
# Содержит в себе описание около 7 тысяч книг, обладает следующими признаками: уникальные номера isbn10 и isbn13, название, подзаголовок, авторы, жанр, описание, год публикации, средний рейтинг, количество страниц и отзывов.
#
# **Описание задачи:** Я буду решать задачу регрессии, чтобы предсказывать рейтинг книги.
#
# **Примечание:**  Есть признак "thumbnail", который представляет из себя изображение, участвовать в решении задачи он не будет, поэтому его можно сразу "дропнуть".

# %%
from google.colab import drive
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
dataset = pd.read_csv('/content/gdrive/MyDrive/Dataset/books.csv')
dataset = dataset.drop(columns=['thumbnail'])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Наглядно представим пропущенные значения:

# %%
cols = dataset.columns
#gray - not missed, red - missed
colours = ['#808080', '#FF0000']
sns.heatmap(dataset[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
for col in dataset.columns:
    pct_missing = np.mean(dataset[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# isbn13 - 0%
# isbn10 - 0%
# title - 0%
# subtitle - 65%
# authors - 1%
# categories - 1%
# description - 4%
# published_year - 0%
# average_rating - 1%
# num_pages - 1%
# ratings_count - 1%

# %% [markdown]
# Рассмотрим типы признаков:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   description     6548 non-null   object
#  7   published_year  6804 non-null   float64
#  8   average_rating  6767 non-null   float64
#  9   num_pages       6767 non-null   float64
#  10  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 585.4+ KB

# %% [markdown]
# Работать будем с признаками: 'published_year', 'num_pages', 'average_rating', 'ratings_count'. Я предположку, что не следует искать связь между isbn10(13) и средней оценкой книги, т.к. isbn - лишь уникальный номер. С текстовыми признаками пока что тоже не будем работать, ограничимся численными признаками и теми категориальными, которые можно обработать и привести к численным ('categories' - хороший кандидат).
#
# Теперь посмотрим на выбросы:

# %%
columns_to_check = dataset[['published_year', 'num_pages', 'average_rating', 'ratings_count']]

columns_to_check

for feature in columns_to_check.columns:
    Q1 = dataset[feature].quantile(0.25)
    Q3 = dataset[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1 * IQR
    upper_bound = Q3 + 1 * IQR
    outliers = (dataset[feature] < lower_bound) | (dataset[feature] > upper_bound)
    print(feature + ': ' + str(outliers.sum()))
# Out:
# published_year: 616
# num_pages: 606
# average_rating: 423
# ratings_count: 1165

# %% [markdown]
# Выбросы есть, и это вполне ожидаемо. Их не критически много, задача все еще очень даже выполнима. Взглянем на еще несколько характеристик:

# %%
min = columns_to_check.apply(lambda x: x.min())
max = columns_to_check.apply(lambda x: x.max())
delta = max - min

print(delta)
# Out:
# published_year        166.0
# num_pages            3342.0
# average_rating          5.0
# ratings_count     5629932.0
# dtype: float64

# %% [markdown]
# Теперь заполним пропущенные значения:

# %%
dataset['categories'].fillna('',inplace=True)
dataset['description'].fillna('',inplace=True)
dataset['authors'].fillna('',inplace=True)
dataset['subtitle'].fillna('',inplace=True)

for column in columns_to_check:
    median_value = dataset[column].median()
    dataset[column].fillna(int(median_value), inplace=True)

for col in dataset.columns:
    pct_missing = np.mean(dataset[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# isbn13 - 0%
# isbn10 - 0%
# title - 0%
# subtitle - 0%
# authors - 0%
# categories - 0%
# description - 0%
# published_year - 0%
# average_rating - 0%
# num_pages - 0%
# ratings_count - 0%

# %% [markdown]
# И обработаем признак 'categories'.  Для этого используем LabelEncoder из библиотеки scikit-learn. Параллельно с этим нормализуем и другие признаки.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

dataset['categories'] = label_encoder.fit_transform(dataset['categories'])

columns_to_normalize = ['categories','published_year', 'average_rating', 'num_pages', 'ratings_count']

scaler = MinMaxScaler()

dataset[columns_to_normalize] = scaler.fit_transform(dataset[columns_to_normalize])

dataset
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0
# 1                                            A Novel
# 2
# 3
# 4
# ...                                              ...
# 6805             Talks with Sri Nisargadatta Maharaj
# 6806
# 6807
# 6808
# 6809  Jeanette Winterson and the Politics of Reading
#
#                                            authors  categories  \
# 0                               Marilynne Robinson    0.601411
# 1                  Charles Osborne;Agatha Christie    0.474427
# 2                             Stephen R. Donaldson    0.082892
# 3                                   Sidney Sheldon    0.601411
# 4                              Clive Staples Lewis    0.349206
# ...                                            ...         ...
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit    0.858907
# 6806                                 Khalil Gibran    0.820106
# 6807                                  Ray Bradbury    0.250441
# 6808                 Georg Wilhelm Friedrich Hegel    0.666667
# 6809                        Helena Grice;Tim Woods    0.761905
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...        0.909639
# 1     A new 'Christie for Christmas' -- a full-lengt...        0.885542
# 2     Volume Two of Stephen Donaldson's acclaimed se...        0.777108
# 3     A memorable, mesmerizing heroine Jennifer -- b...        0.843373
# 4     Lewis' work on the nature of love divides love...        0.897590
# ...                                                 ...             ...
# 6805  This collection of the timeless teachings of o...        0.879518
# 6806                                                           0.843373
# 6807                                                           0.909639
# 6808  Since the three volume edition ofHegel's Philo...        0.771084
# 6809  This is a jubilant and rewarding collection of...        0.873494
#
#       average_rating  num_pages  ratings_count
# 0              0.770   0.073908       0.000064
# 1              0.766   0.072113       0.000917
# 2              0.794   0.143327       0.000031
# 3              0.786   0.153202       0.005246
# 4              0.830   0.050868       0.005983
# ...              ...        ...            ...
# 6805           0.902   0.158887       0.000018
# 6806           0.816   0.022142       0.000058
# 6807           0.796   0.055655       0.001018
# 6808           0.000   0.062837       0.000000
# 6809           0.740   0.040694       0.000002
#
# [6810 rows x 11 columns]

# %%
features = dataset[['categories', 'published_year', 'average_rating', 'num_pages', 'ratings_count']]

correlation_matrix = features.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Есть небольшая положительная корреляция между средней оценкой и количеством страниц, между остальными признаками корелляции практически нет.

# %% [markdown]
# Теперь определимся с методом решения задачи.
#
# **Метод k ближаших соседий** нам **не подходит**, так как он чувствителен к выбросам. Также он медленный.
#
# **Линейная регрессия** нам **не подходит**, так как предполагает простую зависимость данных.
#
# Я предлагаю использовать методы **случайного леса**(без гиперпараметров) и **нейронных сетей**.

# %% [markdown]
# Начнем со случайного леса, для этого разобьем датасет на тестовую и обучающую выборку и запустим на них RandomForestRegressor из scikit-klearn.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

X = dataset.drop(['isbn13','isbn10', 'title', 'subtitle', 'authors', 'description', 'average_rating'], axis=1)
y = dataset['average_rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35)

random_forest = RandomForestRegressor(n_estimators=100, random_state=54)

random_forest.fit(X_train, y_train)

predictions_test = random_forest.predict(X_test)
predictions_train = random_forest.predict(X_train)

r2_test = r2_score(y_test, predictions_test)
r2_train = r2_score(y_train, predictions_train)

mse_test = mean_squared_error(y_test, predictions_test)
mse_train = mean_squared_error(y_train, predictions_train)

print("r2_test =" + str(r2_test) + "MSE ="  + str(mse_test))
print("r2_train =" + str(r2_train) + "MSE =" + str(mse_train))
# Out:
# r2_test =0.07576531536596531MSE =0.004081026340939597
# r2_train =0.8864644682446935MSE =0.0005303646408495266

# %% [markdown]
# r2 на тестовой выборке получился очень низким, это означает, что модель способна "объяснить" ~23% подобранных данных. Несмотря на то, что mse получился очень даже хорошим, данная модель вряд ли подойдет для решения задачи.

# %% [markdown]
# Теперь попробуем нейронную сеть с гиперпараметрами:

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_regression

model = MLPRegressor()

param_grid = {
    'hidden_layer_sizes': [(50,50), (50,100,50), (100,100,100,100)],
    'activation': ['tanh', 'logistic'],
    'solver': ['adam', 'sgd'],
    'max_iter': [1000],
}

grid_search = GridSearchCV(model, param_grid, cv=2, scoring='neg_mean_squared_error', n_jobs=1, verbose=2)
grid_search.fit(X, y)

predictions_test = grid_search.best_estimator_.predict(X_test)
predictions_train = grid_search.best_estimator_.predict(X_train)

r2_test = r2_score(y_test, predictions_test)
r2_train = r2_score(y_train, predictions_train)

mse_test = mean_squared_error(y_test, predictions_test)
mse_train = mean_squared_error(y_train, predictions_train)

print("r2_test =" + str(r2_test) + "MSE ="  + str(mse_test))
print("r2_train =" + str(r2_train) + "MSE =" + str(mse_train))
# Out:
# Fitting 2 folds for each of 12 candidates, totalling 24 fits
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), max_iter=1000, solver=adam; total time=   2.9s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), max_iter=1000, solver=adam; total time=   2.6s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), max_iter=1000, solver=sgd; total time=   3.0s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), max_iter=1000, solver=sgd; total time=   2.0s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=adam; total time=   3.7s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=adam; total time=   6.6s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=sgd; total time=   3.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=sgd; total time=   4.9s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=adam; total time=  10.0s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=adam; total time=   7.0s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=sgd; total time=   7.3s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=sgd; total time=   3.0s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), max_iter=1000, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), max_iter=1000, solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), max_iter=1000, solver=sgd; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), max_iter=1000, solver=sgd; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=adam; total time=   0.7s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=adam; total time=   0.8s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=sgd; total time=   0.6s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 100, 50), max_iter=1000, solver=sgd; total time=   0.8s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=adam; total time=   1.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=adam; total time=   2.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=sgd; total time=   3.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100, 100), max_iter=1000, solver=sgd; total time=   2.8s
# r2_test =-0.020066675638480858MSE =0.00450417955742886
# r2_train =-0.016302960032735347MSE =0.004747510722491329

# %% [markdown]
# Нейронная сеть показала результат хуже, чем случайный лес.

# %% [markdown]
# Выводы:
#
# Я описал задачу, посчитал пропуски и выбросы. Устранил пропуски(медианами либо же пустой строкой), нормализовал признаки и обработал категориальные(их тоже нормализовал), после чего применил методы случайного леса и нейронной сети. Несмотря на нетривиальность и мощность методов и перебор гиперпараметров, я не смог добиться приемлемой r2, хотя ошибка на тестовой выборке получилась малой.
#
# Я предполагаю, что изначальные данные слишком независимы и включение текстовых признаков могло бы улучшить ситуацию, но я пока не знаю, как работать с текстовыми признаками.

# %% [markdown]
# # Дз к 29 декабря:

# %% [markdown]
# Логистическая регрессия используется для задачи классификации, поэтому я буду работать с линейной регрессией:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

X = dataset.drop(['isbn13','isbn10', 'title', 'subtitle', 'authors', 'description', 'average_rating'], axis=1)
y = dataset['average_rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

model = LinearRegression()

model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)


# Вывод результатов
print("r2_test = =", r2_score(y_test, y_test_pred) , "MSE =", mean_squared_error(y_test, y_test_pred))
print("r2_train =",r2_score(y_train, y_train_pred), "MSE =", mean_squared_error(y_train, y_train_pred))
# Out:
# r2_test = = 0.05103847877784207 MSE = 0.004140726097851417
# r2_train = 0.04467510877879566 MSE = 0.004428545500292733

# %% [markdown]
# Как итог, очень низкие значения MSE, но плохие r2. Из плюсов - практически идентичные значения на тестовой и тренировочной выборке => скорее всего нет переобучения.

# %% [markdown]
# Перебор гиперпараметров для случайного леса:

# %%
model = RandomForestRegressor()

X = dataset.drop(['isbn13','isbn10', 'title', 'subtitle', 'authors', 'description', 'average_rating'], axis=1)
y = dataset['average_rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

param_grid = {
    'n_estimators': [100, 200, 300],
    'min_sample_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(model, param_grid, cv=2, scoring='r2', n_jobs=1, verbose=3)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Fitting 2 folds for each of 54 candidates, totalling 108 fits
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.184 total time=   1.5s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.126 total time=   1.2s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.170 total time=   2.3s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.131 total time=   1.6s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.181 total time=   2.2s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.135 total time=   4.8s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.184 total time=   0.9s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.145 total time=   0.9s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.190 total time=   1.4s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.151 total time=   1.3s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.191 total time=   1.9s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.155 total time=   2.3s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.197 total time=   0.6s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.168 total time=   0.6s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.201 total time=   1.2s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.168 total time=   1.2s
# [CV 1/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.199 total time=   2.6s
# [CV 2/2] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.162 total time=   2.5s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.170 total time=   0.9s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.140 total time=   0.7s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.176 total time=   1.4s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.129 total time=   1.5s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.167 total time=   2.2s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.138 total time=   2.2s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.202 total time=   0.7s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.137 total time=   0.6s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.188 total time=   1.8s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.146 total time=   1.9s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.192 total time=   2.6s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.156 total time=   1.8s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.196 total time=   0.6s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.166 total time=   0.6s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.203 total time=   1.1s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.161 total time=   1.2s
# [CV 1/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.197 total time=   1.7s
# [CV 2/2] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.160 total time=   1.7s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=100;, score=0.169 total time=   1.2s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=100;, score=0.102 total time=   1.5s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=200;, score=0.169 total time=   3.2s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=200;, score=0.103 total time=   2.5s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=300;, score=0.171 total time=   3.2s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=2, n_estimators=300;, score=0.103 total time=   3.2s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=100;, score=0.175 total time=   1.0s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=100;, score=0.115 total time=   1.0s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=200;, score=0.182 total time=   2.7s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=200;, score=0.129 total time=   2.8s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=300;, score=0.175 total time=   3.1s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=5, n_estimators=300;, score=0.118 total time=   2.9s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=100;, score=0.179 total time=   0.9s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=100;, score=0.136 total time=   0.9s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=200;, score=0.182 total time=   1.8s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=200;, score=0.134 total time=   2.1s
# [CV 1/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=300;, score=0.180 total time=   4.0s
# [CV 2/2] END bootstrap=True, max_features=None, min_samples_split=10, n_estimators=300;, score=0.134 total time=   2.9s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.087 total time=   1.0s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.041 total time=   0.9s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.088 total time=   1.9s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.057 total time=   1.9s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.090 total time=   3.1s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.041 total time=   4.0s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.127 total time=   1.1s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.106 total time=   0.8s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.125 total time=   1.7s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.108 total time=   1.6s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.127 total time=   2.4s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.096 total time=   2.4s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.145 total time=   0.7s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.122 total time=   0.8s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.148 total time=   2.2s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.114 total time=   2.1s
# [CV 1/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.144 total time=   2.7s
# [CV 2/2] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.119 total time=   2.2s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.077 total time=   1.0s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.037 total time=   0.9s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.076 total time=   1.9s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.036 total time=   1.9s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.088 total time=   4.0s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.045 total time=   3.6s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.126 total time=   0.9s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.101 total time=   0.8s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.124 total time=   1.7s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.104 total time=   1.6s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.119 total time=   2.4s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.100 total time=   2.8s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.140 total time=   1.1s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.114 total time=   1.1s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.137 total time=   2.2s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.119 total time=   1.4s
# [CV 1/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.144 total time=   2.2s
# [CV 2/2] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.116 total time=   2.1s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=100;, score=-0.505 total time=   1.5s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=100;, score=-0.490 total time=   1.4s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=200;, score=-0.501 total time=   3.7s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=200;, score=-0.493 total time=   3.9s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=300;, score=-0.502 total time=   4.5s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=2, n_estimators=300;, score=-0.496 total time=   4.4s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=100;, score=-0.437 total time=   1.6s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=100;, score=-0.451 total time=   1.8s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=200;, score=-0.437 total time=   3.7s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=200;, score=-0.451 total time=   2.5s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=300;, score=-0.437 total time=   4.1s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=5, n_estimators=300;, score=-0.451 total time=   4.2s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=100;, score=-0.261 total time=   1.8s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=100;, score=-0.261 total time=   1.7s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=200;, score=-0.261 total time=   2.8s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=200;, score=-0.261 total time=   2.3s
# [CV 1/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=300;, score=-0.262 total time=   3.7s
# [CV 2/2] END bootstrap=False, max_features=None, min_samples_split=10, n_estimators=300;, score=-0.261 total time=   3.9s
# Best Hyperparameters: {'bootstrap': True, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}
# R-squared: 0.14582065076466333

# %%
results = grid_search.cv_results_['mean_test_score']
params_combinations = [str(params) for params in grid_search.cv_results_['params']]

plt.figure(figsize=(20, 10))
plt.plot(results)
plt.xticks(np.arange(len(params_combinations)), params_combinations, rotation=45, ha='right')

plt.xlabel('params')
plt.ylabel('mean_test_score')
plt.tight_layout()
plt.show()

# %%
model = grid_search.best_estimator_

Y_test_pred = model.predict(X_test)
Y_train_pred = model.predict(X_train)

mse_test = mean_squared_error(y_test, Y_test_pred)
mse_train = mean_squared_error(y_train, Y_train_pred)

r2_test = r2_score(y_test, Y_test_pred)
r2_train = r2_score(y_train, Y_train_pred)

print("mse_test:", mse_test)
print("r2_test:", r2_test)

print("mse_train:", mse_train)
print("r2_train:", r2_train)
# Out:
# mse_test: 0.0037271508322796183
# r2_test: 0.14582065076466333
# mse_train: 0.001647191699533803
# r2_train: 0.6446681577340498

# %% [markdown]
# Есть незначительные различия между mse на тренировочной и тестовой выборках, но я считаю, что ими можно пренебречь. Что менее интуитивно - r2 на тренировочной выборке хуже, чем на тестовой! Единственное мое предположение - изначально данные настолько неописуемы, что тестовую выборку проще описать той же моделью, чем тренировочную, из-за ее размера.

# %% [markdown]
# Т.к. mse получалось приемлемым, я решил оценить влияние гиперпараметров на r2. Из интересного - полный провал при использовании 'max_features' = None. r2 может быть отрицательным, обычно это означает, что модель плохо описывает данные (fitting the data), вот наглядный пример:
#
# ![](https://drive.google.com/uc?export=view&id=1iQQ93ze6jVIg099An9LnxdZfVzpcN_tE)
#
# Хорошая модель может иметь низкое значение r2, важна совокупность метрик в целом, но ради эксперимента я попытался увеличить r2. Mse при этом остался низким.
#
# **Теперь опишем полносвязную нейронную сеть:**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

X = dataset.drop(['isbn13','isbn10', 'title', 'subtitle', 'authors', 'description', 'average_rating'], axis=1)
y = dataset['average_rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

input_dim = X_train.shape[1]
# 2 layers
model = Sequential()
model.add(Dense(10, input_dim=input_dim, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# compile
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)

loss, mse = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test MSE: {mse}')
# Out:
# Epoch 1/50
# 307/307 [==============================] - 3s 5ms/step - loss: 0.3650 - mse: 0.3650 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 2/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 3/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 4/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 5/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 6/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 7/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 8/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 9/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 10/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 11/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 12/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 13/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 14/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 15/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 16/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 17/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 18/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 19/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 20/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 21/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 22/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 23/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 24/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 25/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 26/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 27/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 28/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 29/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 30/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 31/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 32/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 33/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 34/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 35/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 36/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 37/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 38/50
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 39/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 40/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 41/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 42/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 43/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 44/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 45/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 46/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 47/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 48/50
# 307/307 [==============================] - 1s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 49/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 50/50
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0056 - val_mse: 0.0056
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0040 - mse: 0.0040
# Test Loss: 0.004031030926853418, Test MSE: 0.004031030926853418

# %%
Y_test_pred = model.predict(X_test)
Y_train_pred = model.predict(X_train)

mse_test = mean_squared_error(y_test, Y_test_pred)
mse_train = mean_squared_error(y_train, Y_train_pred)

r2_test = r2_score(y_test, Y_test_pred)
r2_train = r2_score(y_train, Y_train_pred)

print("mse_test:", mse_test)
print("r2_test:", r2_test)

print("mse_train:", mse_train)
print("r2_train:", r2_train)
# Out:
# 43/43 [==============================] - 0s 2ms/step
# 171/171 [==============================] - 0s 1ms/step
# mse_test: 0.004031032241208849
# r2_test: 0.07617784965346475
# mse_train: 0.00434116453454178
# r2_train: 0.0635249120822311

# %% [markdown]
# Mse все еще низок, а вот r2 по сравнению со случайным лесом, уменьшилось с 0.15 до 0.07 на тестовой выборке. Результаты тестовой и тренирововчной выборок схожи, что очень хорошо, скорее всего, мы не переобучили модель.

# %% [markdown]
# # Выводы:
#
#
#
# 1.   Лучше всех себя показал случайный лес с гиперпараметрами.
# 2.   Линейная регрессия скорее всего не подходит для решения данной задачи.
# 3.   Несмотря на низкое значение r2, mse остается очень малым. Я не могу сделать однозначный вывод о переобучении или недообучении, так как на тестовой выборке модель показывает себя очень неплохо. Если бы я мог как-то учесть текстовый признак и имел бы больше вхождений в датасете, то скорее всего, модели работали бы лучше.
# 4.   В датасете много пропущенных значений, это негативно сказывается на обучении.
# 5.   Из предложенных методов самыми подходящими для решения данной задачи я считаю случайный лес и полносвязную нейронную сеть.
# 6.   При подборе гиперпараметров для нейронной сети можно было бы достичь результатов не хуже, а может даже и лучше, чем у случайного леса.
#
# *Прим:* Я не стал строить confusion matrix и использовать логистическую регрессию, так как изначально не решал задачу классификации. Confusin matrix в чистом виде не может быть построена для задачи регрессии
